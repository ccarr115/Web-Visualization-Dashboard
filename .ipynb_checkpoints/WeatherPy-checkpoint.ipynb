# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = "7af6773cd27b08df16f9f7f1bc7714a0"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=butaritari
# Processing Record 2 of Set 1 | poso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=poso
# Processing Record 3 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=mar%20del%20plata
# Processing Record 4 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bluff
# Processing Record 5 of Set 1 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=mount%20gambier
# Processing Record 6 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=iqaluit
# Processing Record 7 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=arraial%20do%20cabo
# Processing Record 8 of Set 1 | buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=buchanan
# Processing Record 9 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=saint%20george
# Processing Record 10 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=busselton
# Processing Record 11 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bambous%20virieux
# Processing Record 12 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=rikitea
# Processing Record 14 of Set 1 | atlantis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=atlantis
# Processing Record 15 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=qaanaaq
# Processing Record 16 of Set 1 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=saskylakh
# Processing Record 18 of Set 1 | concarneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=concarneau
# Processing Record 19 of Set 1 | palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=palauig
# Processing Record 20 of Set 1 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ranong
# Processing Record 21 of Set 1 | asfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=asfi
# City not found. Skipping...
# Processing Record 22 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nanortalik
# Processing Record 23 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=khatanga
# Processing Record 24 of Set 1 | tocache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tocache
# Processing Record 25 of Set 1 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=chapais
# Processing Record 26 of Set 1 | kurmanayevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kurmanayevka
# Processing Record 27 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=thompson
# Processing Record 28 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=punta%20arenas
# Processing Record 29 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=atuona
# Processing Record 30 of Set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=belushya%20guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=jamestown
# Processing Record 32 of Set 1 | sheksna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sheksna
# Processing Record 33 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nikolskoye
# Processing Record 34 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hobart
# Processing Record 35 of Set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lagoa
# Processing Record 36 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bethel
# Processing Record 37 of Set 1 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=portland
# Processing Record 38 of Set 1 | ozernovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ozernovskiy
# Processing Record 39 of Set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=constitucion
# Processing Record 40 of Set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hasaki
# Processing Record 41 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=narsaq
# Processing Record 42 of Set 1 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=strezhevoy
# Processing Record 43 of Set 1 | ginda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ginda
# Processing Record 44 of Set 1 | kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kidal
# Processing Record 45 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hithadhoo
# Processing Record 46 of Set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=pangnirtung
# Processing Record 47 of Set 1 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=yar-sale
# Processing Record 48 of Set 1 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hambantota
# Processing Record 49 of Set 1 | ramasukha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ramasukha
# City not found. Skipping...
# Processing Record 50 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hilo
# Processing Record 0 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bredasdorp
# Processing Record 1 of Set 2 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 2 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=san%20policarpo
# Processing Record 3 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kapaa
# Processing Record 4 of Set 2 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=along
# Processing Record 5 of Set 2 | almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=almaznyy
# Processing Record 6 of Set 2 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kavieng
# Processing Record 7 of Set 2 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=moron
# Processing Record 8 of Set 2 | lusambo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lusambo
# Processing Record 9 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=yellowknife
# Processing Record 10 of Set 2 | keuruu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=keuruu
# Processing Record 11 of Set 2 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=pisco
# Processing Record 12 of Set 2 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tuatapere
# Processing Record 13 of Set 2 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tilichiki
# Processing Record 14 of Set 2 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tecoanapa
# Processing Record 15 of Set 2 | miandrivazo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=miandrivazo
# Processing Record 16 of Set 2 | ivanovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ivanovka
# Processing Record 17 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=vaini
# Processing Record 18 of Set 2 | kutahya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kutahya
# Processing Record 19 of Set 2 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=san%20patricio
# Processing Record 20 of Set 2 | ubatuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ubatuba
# Processing Record 21 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=georgetown
# Processing Record 22 of Set 2 | jiuquan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=jiuquan
# Processing Record 23 of Set 2 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=port%20hedland
# Processing Record 24 of Set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=provideniya
# Processing Record 25 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hermanus
# Processing Record 26 of Set 2 | dolbeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 2 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=college
# Processing Record 28 of Set 2 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=riyadh
# Processing Record 29 of Set 2 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=paamiut
# Processing Record 30 of Set 2 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=san%20cristobal
# Processing Record 31 of Set 2 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=fortuna
# Processing Record 32 of Set 2 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nishihara
# Processing Record 33 of Set 2 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=maragogi
# Processing Record 34 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ponta%20do%20sol
# Processing Record 35 of Set 2 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=katsuura
# Processing Record 36 of Set 2 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=cherskiy
# Processing Record 37 of Set 2 | boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=boende
# Processing Record 38 of Set 2 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ketchikan
# Processing Record 39 of Set 2 | abu zabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=abu%20zabad
# Processing Record 40 of Set 2 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ponta%20delgada
# Processing Record 41 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=cape%20town
# Processing Record 43 of Set 2 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=faya
# Processing Record 44 of Set 2 | haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=haibowan
# City not found. Skipping...
# Processing Record 45 of Set 2 | chirongui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=chirongui
# Processing Record 46 of Set 2 | banepa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=banepa
# Processing Record 47 of Set 2 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sioux%20lookout
# Processing Record 48 of Set 2 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=vao
# Processing Record 49 of Set 2 | humberto de campos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=humberto%20de%20campos
# Processing Record 0 of Set 3 | gisborne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=gisborne
# Processing Record 1 of Set 3 | kohlu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kohlu
# Processing Record 2 of Set 3 | abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=abha
# Processing Record 3 of Set 3 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=san%20juan
# Processing Record 4 of Set 3 | kirpilskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kirpilskaya
# Processing Record 5 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=castro
# Processing Record 6 of Set 3 | santa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=santa%20maria
# Processing Record 7 of Set 3 | deoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=deoria
# Processing Record 8 of Set 3 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=morondava
# Processing Record 9 of Set 3 | nisia floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nisia%20floresta
# Processing Record 10 of Set 3 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kalmunai
# Processing Record 11 of Set 3 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=plettenberg%20bay
# Processing Record 12 of Set 3 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ostrovnoy
# Processing Record 13 of Set 3 | soc trang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=soc%20trang
# Processing Record 14 of Set 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=puerto%20ayora
# Processing Record 15 of Set 3 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 16 of Set 3 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bengkulu
# City not found. Skipping...
# Processing Record 17 of Set 3 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ushuaia
# Processing Record 18 of Set 3 | kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kurilsk
# Processing Record 19 of Set 3 | ascension
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ascension
# City not found. Skipping...
# Processing Record 20 of Set 3 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sorong
# Processing Record 21 of Set 3 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=rio%20gallegos
# Processing Record 22 of Set 3 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dingle
# Processing Record 23 of Set 3 | la cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=la%20cruz
# Processing Record 24 of Set 3 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=port%20alfred
# Processing Record 25 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=upernavik
# Processing Record 26 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=avarua
# Processing Record 27 of Set 3 | iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=iskateley
# Processing Record 28 of Set 3 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=praia%20da%20vitoria
# Processing Record 29 of Set 3 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=evensk
# Processing Record 30 of Set 3 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=clyde%20river
# Processing Record 31 of Set 3 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=saint%20anthony
# Processing Record 32 of Set 3 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=albany
# Processing Record 33 of Set 3 | ternovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ternovka
# Processing Record 34 of Set 3 | orillia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=orillia
# Processing Record 35 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=port%20elizabeth
# Processing Record 36 of Set 3 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=porto%20novo
# Processing Record 37 of Set 3 | copiapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=copiapo
# Processing Record 38 of Set 3 | weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=weligama
# Processing Record 39 of Set 3 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=grand%20gaube
# Processing Record 40 of Set 3 | menzelinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=menzelinsk
# Processing Record 41 of Set 3 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=codrington
# Processing Record 42 of Set 3 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=severo-kurilsk
# Processing Record 43 of Set 3 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=verkhoyansk
# Processing Record 44 of Set 3 | kathmandu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kathmandu
# Processing Record 45 of Set 3 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=mataura
# Processing Record 46 of Set 3 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=namatanai
# Processing Record 47 of Set 3 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=namibe
# Processing Record 48 of Set 3 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=boyolangu
# Processing Record 49 of Set 3 | timmins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=timmins
# Processing Record 0 of Set 4 | dalby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dalby
# Processing Record 1 of Set 4 | veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=veraval
# Processing Record 2 of Set 4 | zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=zhangye
# Processing Record 3 of Set 4 | altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=altay
# Processing Record 4 of Set 4 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dikson
# Processing Record 5 of Set 4 | levokumka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=levokumka
# Processing Record 6 of Set 4 | kapit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kapit
# Processing Record 7 of Set 4 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hami
# Processing Record 8 of Set 4 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 4 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lebu
# Processing Record 10 of Set 4 | guiratinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=guiratinga
# Processing Record 11 of Set 4 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=komsomolskiy
# Processing Record 12 of Set 4 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=matara
# Processing Record 13 of Set 4 | manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=manta
# Processing Record 14 of Set 4 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=thinadhoo
# Processing Record 15 of Set 4 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=klaksvik
# Processing Record 16 of Set 4 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=chuy
# Processing Record 17 of Set 4 | owosso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=owosso
# Processing Record 18 of Set 4 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ambon
# Processing Record 19 of Set 4 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=salalah
# Processing Record 20 of Set 4 | san jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=san%20jose
# Processing Record 21 of Set 4 | rapid valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=rapid%20valley
# Processing Record 22 of Set 4 | hatillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hatillo
# Processing Record 23 of Set 4 | praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=praya
# Processing Record 24 of Set 4 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=margate
# Processing Record 25 of Set 4 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=norman%20wells
# Processing Record 26 of Set 4 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=xining
# Processing Record 27 of Set 4 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kahului
# Processing Record 28 of Set 4 | high level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=high%20level
# Processing Record 29 of Set 4 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=broome
# Processing Record 30 of Set 4 | ilinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ilinskiy
# Processing Record 31 of Set 4 | prokuplje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=prokuplje
# Processing Record 32 of Set 4 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=pevek
# Processing Record 33 of Set 4 | soledar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=soledar
# Processing Record 34 of Set 4 | tsogni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tsogni
# Processing Record 35 of Set 4 | adana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=adana
# Processing Record 36 of Set 4 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nouadhibou
# Processing Record 37 of Set 4 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tuktoyaktuk
# Processing Record 38 of Set 4 | ladario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ladario
# Processing Record 39 of Set 4 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lompoc
# Processing Record 40 of Set 4 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=vardo
# Processing Record 41 of Set 4 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=new%20norfolk
# Processing Record 42 of Set 4 | suzu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=suzu
# City not found. Skipping...
# Processing Record 43 of Set 4 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sur
# Processing Record 44 of Set 4 | westfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=westfield
# Processing Record 45 of Set 4 | minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=minab
# Processing Record 46 of Set 4 | birjand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=birjand
# Processing Record 47 of Set 4 | tulle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tulle
# Processing Record 48 of Set 4 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bandarbeyla
# Processing Record 49 of Set 4 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=taolanaro
# City not found. Skipping...
# Processing Record 0 of Set 5 | mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=mana
# Processing Record 1 of Set 5 | whitianga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=whitianga
# Processing Record 2 of Set 5 | viligili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=viligili
# City not found. Skipping...
# Processing Record 3 of Set 5 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=richards%20bay
# Processing Record 4 of Set 5 | ziro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ziro
# Processing Record 5 of Set 5 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=broken%20hill
# Processing Record 6 of Set 5 | ada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ada
# Processing Record 7 of Set 5 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lasa
# Processing Record 8 of Set 5 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kaitangata
# Processing Record 9 of Set 5 | auray
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=auray
# Processing Record 10 of Set 5 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=leningradskiy
# Processing Record 11 of Set 5 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=cidreira
# Processing Record 12 of Set 5 | smolenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=smolenka
# Processing Record 13 of Set 5 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=victoria
# Processing Record 14 of Set 5 | beidao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=beidao
# Processing Record 15 of Set 5 | psebay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=psebay
# Processing Record 16 of Set 5 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=egvekinot
# Processing Record 17 of Set 5 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 5 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sisimiut
# Processing Record 19 of Set 5 | jacmel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=jacmel
# Processing Record 20 of Set 5 | casper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=casper
# Processing Record 21 of Set 5 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=waipawa
# Processing Record 22 of Set 5 | bela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bela
# Processing Record 23 of Set 5 | general roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=general%20roca
# Processing Record 24 of Set 5 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tarko-sale
# Processing Record 25 of Set 5 | topolobampo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=topolobampo
# Processing Record 26 of Set 5 | guanica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=guanica
# Processing Record 27 of Set 5 | miyazu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=miyazu
# Processing Record 28 of Set 5 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kruisfontein
# Processing Record 29 of Set 5 | jiamusi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=jiamusi
# Processing Record 30 of Set 5 | menongue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=menongue
# Processing Record 31 of Set 5 | dakar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dakar
# Processing Record 32 of Set 5 | lodja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lodja
# Processing Record 33 of Set 5 | solntsevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=solntsevo
# Processing Record 34 of Set 5 | uruzgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=uruzgan
# Processing Record 35 of Set 5 | jidvei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=jidvei
# Processing Record 36 of Set 5 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 5 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=barrow
# Processing Record 38 of Set 5 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=port-cartier
# Processing Record 39 of Set 5 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tual
# Processing Record 40 of Set 5 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=cap%20malheureux
# Processing Record 41 of Set 5 | cozumel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=cozumel
# City not found. Skipping...
# Processing Record 42 of Set 5 | capao da canoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=capao%20da%20canoa
# Processing Record 43 of Set 5 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hofn
# Processing Record 44 of Set 5 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dunedin
# Processing Record 45 of Set 5 | krasnaya polyana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=krasnaya%20polyana
# Processing Record 46 of Set 5 | dzhebariki-khaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dzhebariki-khaya
# Processing Record 47 of Set 5 | banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=banjar
# Processing Record 48 of Set 5 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=torbay
# Processing Record 49 of Set 5 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hammerfest
# Processing Record 0 of Set 6 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=souillac
# Processing Record 1 of Set 6 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 6 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tiarei
# Processing Record 3 of Set 6 | plattsburgh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=plattsburgh
# Processing Record 4 of Set 6 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=russell
# Processing Record 5 of Set 6 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nantucket
# Processing Record 6 of Set 6 | furano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=furano
# Processing Record 7 of Set 6 | koryazhma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=koryazhma
# Processing Record 8 of Set 6 | barraute
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=barraute
# Processing Record 9 of Set 6 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=cayenne
# Processing Record 10 of Set 6 | placido de castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=placido%20de%20castro
# Processing Record 11 of Set 6 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=carnarvon
# Processing Record 12 of Set 6 | helong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=helong
# Processing Record 13 of Set 6 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=petropavlovsk-kamchatskiy
# Processing Record 14 of Set 6 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=qaqortoq
# Processing Record 15 of Set 6 | urdzhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 6 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=viedma
# Processing Record 17 of Set 6 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=saint-pierre
# Processing Record 18 of Set 6 | nova olimpia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nova%20olimpia
# Processing Record 19 of Set 6 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=puerto%20escondido
# Processing Record 20 of Set 6 | camopi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=camopi
# Processing Record 21 of Set 6 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=half%20moon%20bay
# Processing Record 22 of Set 6 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=usinsk
# Processing Record 23 of Set 6 | diourbel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=diourbel
# Processing Record 24 of Set 6 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=arman
# Processing Record 25 of Set 6 | skalistyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 6 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=talnakh
# Processing Record 27 of Set 6 | sinamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sinamar
# Processing Record 28 of Set 6 | altus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=altus
# Processing Record 29 of Set 6 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=east%20london
# Processing Record 30 of Set 6 | foindu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=foindu
# Processing Record 31 of Set 6 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=port%20keats
# Processing Record 32 of Set 6 | oxbow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=oxbow
# Processing Record 33 of Set 6 | lakselv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lakselv
# Processing Record 34 of Set 6 | jiwani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=jiwani
# Processing Record 35 of Set 6 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=chokurdakh
# Processing Record 36 of Set 6 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=touros
# Processing Record 37 of Set 6 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=saint-philippe
# Processing Record 38 of Set 6 | vikhorevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=vikhorevka
# Processing Record 39 of Set 6 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sao%20joao%20da%20barra
# Processing Record 40 of Set 6 | yarke pole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=yarke%20pole
# Processing Record 41 of Set 6 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=belmonte
# Processing Record 42 of Set 6 | ihosy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ihosy
# Processing Record 43 of Set 6 | nata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nata
# Processing Record 44 of Set 6 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sabang
# Processing Record 45 of Set 6 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=mitu
# Processing Record 46 of Set 6 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=te%20anau
# Processing Record 47 of Set 6 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sitka
# Processing Record 48 of Set 6 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=coahuayana
# Processing Record 49 of Set 6 | great falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=great%20falls
# Processing Record 0 of Set 7 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nome
# Processing Record 1 of Set 7 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=deputatskiy
# Processing Record 2 of Set 7 | hirna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=hirna
# Processing Record 3 of Set 7 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=cabo%20san%20lucas
# Processing Record 4 of Set 7 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ilulissat
# Processing Record 5 of Set 7 | chokwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=chokwe
# City not found. Skipping...
# Processing Record 6 of Set 7 | general pico
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=noumea
# Processing Record 19 of Set 11 | llandrindod wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=llandrindod%20wells
# Processing Record 20 of Set 11 | leeuwarden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=leeuwarden
# Processing Record 21 of Set 11 | loyabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=loyabad
# City not found. Skipping...
# Processing Record 22 of Set 11 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=svetlaya
# Processing Record 23 of Set 11 | camana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=camana
# City not found. Skipping...
# Processing Record 24 of Set 11 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=quatre%20cocos
# Processing Record 25 of Set 11 | salisbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=salisbury
# Processing Record 26 of Set 11 | gediz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=gediz
# Processing Record 27 of Set 11 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=avera
# Processing Record 28 of Set 11 | west bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=west%20bay
# Processing Record 29 of Set 11 | bodden town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bodden%20town
# Processing Record 30 of Set 11 | nova russas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nova%20russas
# Processing Record 31 of Set 11 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=goderich
# Processing Record 32 of Set 11 | kita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kita
# Processing Record 33 of Set 11 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=okha
# Processing Record 34 of Set 11 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=meulaboh
# Processing Record 35 of Set 11 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kodiak
# Processing Record 36 of Set 11 | naftah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=naftah
# City not found. Skipping...
# Processing Record 37 of Set 11 | sunndalsora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sunndalsora
# Processing Record 38 of Set 11 | filingue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=filingue
# Processing Record 39 of Set 11 | ibipeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ibipeba
# Processing Record 40 of Set 11 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=honiara
# Processing Record 41 of Set 11 | brownsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=brownsville
# Processing Record 42 of Set 11 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=urumqi
# City not found. Skipping...
# Processing Record 43 of Set 11 | mutis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=mutis
# Processing Record 44 of Set 11 | cascais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=cascais
# Processing Record 45 of Set 11 | jieshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=jieshi
# Processing Record 46 of Set 11 | deniliquin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=deniliquin
# Processing Record 47 of Set 11 | rotenburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=rotenburg
# Processing Record 48 of Set 11 | kampene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kampene
# Processing Record 49 of Set 11 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=esperance
# Processing Record 0 of Set 12 | barra patuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=barra%20patuca
# Processing Record 1 of Set 12 | sri aman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sri%20aman
# Processing Record 2 of Set 12 | shaoyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=shaoyang
# Processing Record 3 of Set 12 | lisala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lisala
# Processing Record 4 of Set 12 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tazovskiy
# Processing Record 5 of Set 12 | cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=cururupu
# Processing Record 6 of Set 12 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=abu%20samrah
# Processing Record 7 of Set 12 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=vostok
# Processing Record 8 of Set 12 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bac%20lieu
# City not found. Skipping...
# Processing Record 9 of Set 12 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=geraldton
# Processing Record 10 of Set 12 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=talcahuano
# Processing Record 11 of Set 12 | westerland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=westerland
# Processing Record 12 of Set 12 | opobo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=opobo
# City not found. Skipping...
# Processing Record 13 of Set 12 | dimbokro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dimbokro
# Processing Record 14 of Set 12 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=srednekolymsk
# Processing Record 15 of Set 12 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=grindavik
# Processing Record 16 of Set 12 | vung tau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=vung%20tau
# Processing Record 17 of Set 12 | chalus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=chalus
# Processing Record 18 of Set 12 | scarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=scarborough
# Processing Record 19 of Set 12 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bathsheba
# Processing Record 20 of Set 12 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nyurba
# Processing Record 21 of Set 12 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=bubaque
# Processing Record 22 of Set 12 | mariental
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=mariental
# Processing Record 23 of Set 12 | caetite
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=caetite
# Processing Record 24 of Set 12 | araguaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=araguaina
# Processing Record 25 of Set 12 | qui nhon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=qui%20nhon
# City not found. Skipping...
# Processing Record 26 of Set 12 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=poum
# Processing Record 27 of Set 12 | dobris
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dobris
# Processing Record 28 of Set 12 | santa isabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=santa%20isabel
# Processing Record 29 of Set 12 | lai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lai
# Processing Record 30 of Set 12 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kangaatsiaq
# Processing Record 31 of Set 12 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=vanavara
# Processing Record 32 of Set 12 | sahuaripa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sahuaripa
# Processing Record 33 of Set 12 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=axim
# Processing Record 34 of Set 12 | kondopoga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kondopoga
# Processing Record 35 of Set 12 | sedniv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=sedniv
# Processing Record 36 of Set 12 | villarrica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=villarrica
# Processing Record 37 of Set 12 | arizona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=arizona
# Processing Record 38 of Set 12 | juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=juneau
# Processing Record 39 of Set 12 | anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=anloga
# Processing Record 40 of Set 12 | warri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=warri
# Processing Record 41 of Set 12 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=umm%20lajj
# Processing Record 42 of Set 12 | ramsar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ramsar
# Processing Record 43 of Set 12 | correntina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=correntina
# Processing Record 44 of Set 12 | dolores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=dolores
# Processing Record 45 of Set 12 | presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=presidencia%20roque%20saenz%20pena
# Processing Record 46 of Set 12 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=chicama
# Processing Record 47 of Set 12 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ucluelet
# Processing Record 48 of Set 12 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=omsukchan
# Processing Record 49 of Set 12 | lardos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=lardos
# Processing Record 0 of Set 13 | qingdao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=qingdao
# Processing Record 1 of Set 13 | palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=palu
# Processing Record 2 of Set 13 | pirganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=pirganj
# Processing Record 3 of Set 13 | oskarshamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=oskarshamn
# Processing Record 4 of Set 13 | tortoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=tortoli
# Processing Record 5 of Set 13 | chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=chumikan
# Processing Record 6 of Set 13 | kalur kot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=kalur%20kot
# Processing Record 7 of Set 13 | ojinaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=ojinaga
# Processing Record 8 of Set 13 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=batemans%20bay
# Processing Record 9 of Set 13 | gidole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=gidole
# Processing Record 10 of Set 13 | terme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=terme
# Processing Record 11 of Set 13 | nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=nago
# Processing Record 12 of Set 13 | naryan-mar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=naryan-mar
# Processing Record 13 of Set 13 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=adrar
# Processing Record 14 of Set 13 | siocon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=siocon
# Processing Record 15 of Set 13 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=gamba
# Processing Record 16 of Set 13 | porto de moz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=porto%20de%20moz
# Processing Record 17 of Set 13 | thoen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=thoen
# Processing Record 18 of Set 13 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=naze
# Processing Record 19 of Set 13 | punta alta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af6773cd27b08df16f9f7f1bc7714a0&q=punta%20alta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv("cities.csv", index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     butaritari          58      KI  1568783237        57   3.07  172.79
# 1           poso          72      ID  1568783237        42  -1.40  120.75
# 2  mar del plata          87      AR  1568783237        61 -46.43  -67.52
# 3          bluff           0      AU  1568783237        18 -23.58  149.07
# 4  mount gambier           2      AU  1568783138        48 -37.83  140.78
#
#    Max Temp  Wind Speed
# 0     85.37        2.10
# 1     79.25        6.53
# 2     43.61       12.03
# 3     85.19        7.90
# 4     60.80       11.41

# %% [markdown]
# ## Latitude vs Temperature Plot

# %%
# Build scatter plot for latitude vs temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()
