# %%
import pandas as pd

# %%
df = pd.read_csv('cities.csv')
df.head()
# Out:
#    City_ID           City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0     butaritari          58      KI  1568783237        57   3.07
# 1        1           poso          72      ID  1568783237        42  -1.40
# 2        2  mar del plata          87      AR  1568783237        61 -46.43
# 3        3          bluff           0      AU  1568783237        18 -23.58
# 4        4  mount gambier           2      AU  1568783138        48 -37.83
#
#       Lng  Max Temp  Wind Speed
# 0  172.79     85.37        2.10
# 1  120.75     79.25        6.53
# 2  -67.52     43.61       12.03
# 3  149.07     85.19        7.90
# 4  140.78     60.80       11.41

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City_ID</th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>butaritari</td>\n      <td>58</td>\n      <td>KI</td>\n      <td>1568783237</td>\n      <td>57</td>\n      <td>3.07</td>\n      <td>172.79</td>\n      <td>85.37</td>\n      <td>2.10</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>poso</td>\n      <td>72</td>\n      <td>ID</td>\n      <td>1568783237</td>\n      <td>42</td>\n      <td>-1.40</td>\n      <td>120.75</td>\n      <td>79.25</td>\n      <td>6.53</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>mar del plata</td>\n      <td>87</td>\n      <td>AR</td>\n      <
# ...

# %%
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>City_ID</th>      <th>City</th>      <th>Cloudiness</th>      <th>Country</th>      <th>Date</th>      <th>Humidity</th>      <th>Lat</th>      <th>Lng</th>      <th>Max Temp</th>      <th>Wind Speed</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>0</td>      <td>butaritari</td>      <td>58</td>      <td>KI</td>      <td>1568783237</td>      <td>57</td>      <td>3.07</td>      <td>172.79</td>      <td>85.37</td>      <td>2.10</td>    </tr>    <tr>      <th>1</th>      <td>1</td>      <td>poso</td>      <td>72</td>      <td>ID</td>      <td>1568783237</td>      <td>42</td>      <td>-1.40</td>      <td>120.75</td>      <td>79.25</td>      <td>6.53</td>    </tr>    <tr>      <th>2</th>      <td>2</td>      <td>mar del plata</td>      <td>87</td>      <td>AR</td>      <td>1568783237</td>      <td>61</td>      <td>-46.43</td>      <td>-67.52</td>      <td>43.61</td> 
# ...

# %%
df.to_html('table.html')
